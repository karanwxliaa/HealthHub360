# %% [markdown]
# # Test Notebook for Audio Processing

# %%
import base64 as bs
import pydub as pd

# %% [markdown]
# # Audio as base64 string

# %%
encoding_str="""..."""

#base64 string to .ogx
decode_bytes = bs.b64decode(encoding_str)
with open('test' + '.ogx', "wb") as wav_file:
    wav_file.write(decode_bytes)

# %% [markdown]
# # .ogx to .wav

# %%
from pydub import AudioSegment

# Open the ogx file with pydub
audio = AudioSegment.from_file("test.ogx", format="ogg")

# Export the audio as wav
audio.export("test.wav", format="wav")
# Out:
# <_io.BufferedRandom name='test.wav'>

# %% [markdown]
# # Calculate the time taken to read the text

# %%
import wave
import contextlib
fname = 'test.wav'
with contextlib.closing(wave.open(fname,'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    duration = frames / float(rate)
    print(duration)
# Out:
# 2.248

# %% [markdown]
# # Speech to Text

# %%
import speech_recognition as sr
from difflib import SequenceMatcher as sm
r = sr.Recognizer()
# Reading Audio file as source
#  listening  the  аudiо  file  аnd  stоre  in  аudiо_text  vаriаble
with sr.AudioFile('test.wav') as source:
    audio_text = r.listen(source)
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
    except:
         print('Sorry.. run again...')

print(sm(None,text,'hello hello hello').ratio())
# Out:
# Converting audio transcripts into text ...
# hello hello hello
# 1.0

# %%
# !pip3 install SpeechRecognition
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Putting it together

# %%
import base64 as bs 
import speech_recognition as sr
from difflib import SequenceMatcher as sm
import speech_recognition as sr
from difflib import SequenceMatcher as sm
from pydub import AudioSegment
import wave
import contextlib



b64str=
orgstr=
reqduration=

decode_bytes = bs.b64decode(b64str)
with open('test' + '.ogx', "wb") as wav_file:
    wav_file.write(decode_bytes)


# Open the ogx file with pydub
audio = AudioSegment.from_file("test.ogx", format="ogg")

# Export the audio as wav
audio.export("test.wav", format="wav")

fname = 'test.wav'
with contextlib.closing(wave.open(fname,'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    actual_duration = frames / float(rate)
    

r = sr.Recognizer()
# Reading Audio file as source
#  listening  the  аudiо  file  аnd  stоre  in  аudiо_text  vаriаble
with sr.AudioFile('test.wav') as source:
    audio_text = r.listen(source)
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
    except:
         print('Sorry.. run again...')

acc = sm(None,text,orgstr).ratio()
# Out:
#   File "/var/folders/lr/tv_mh2r13bb7xs3k5qmj606m0000gn/T/ipykernel_87654/2087421958.py", line 12
#     b64str=
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Testing the Deployed API

# %%
import requests

# %%
URL='https://us-central1-augmented-axe-380213.cloudfunctions.net/dyslexai'

# %%
send={
    "basestr":txt,
    "original":'hello hello hello',
    "duration":'4'
}

# %%
r=requests.post(URL,json=send)

# %%
r.status_code
# Out:
# 200

# %%
r.content
# Out:
# b'{"acc":1.0,"score":100,"tm":2.7958333333333334}\n'

# %%
len('data:audio/mpeg-3;base64,')
# Out:
# 25

# %%
txt='data:audio/mpeg-3;base64,...'

# %%
len(txt[txt.index(',')+1:])-len(txt)
# Out:
# -25
